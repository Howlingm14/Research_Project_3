# %%
import time
start_time = time.time()
while True:
  time.sleep(600)
  Current_time = time.time()-start_time
  hours = Current_time//3600
  minutes = Current_time//60-hours*60
  print("Hours: ", hours, "Minutes: ", minutes)
# Out:
# Hours:  0.0 Minutes:  10.0
# Hours:  0.0 Minutes:  20.0
# Hours:  0.0 Minutes:  30.0
# Hours:  0.0 Minutes:  40.0
# Hours:  0.0 Minutes:  50.0
# Hours:  1.0 Minutes:  0.0
# Hours:  1.0 Minutes:  10.0
# Hours:  1.0 Minutes:  20.0
# Hours:  1.0 Minutes:  30.0
# Hours:  1.0 Minutes:  40.0
# Hours:  1.0 Minutes:  50.0
# Hours:  2.0 Minutes:  0.0
# Hours:  2.0 Minutes:  10.0
# Hours:  2.0 Minutes:  20.0
# Hours:  2.0 Minutes:  30.0
# Hours:  2.0 Minutes:  40.0
# Hours:  2.0 Minutes:  50.0
# Hours:  3.0 Minutes:  0.0
# Hours:  3.0 Minutes:  10.0
# Hours:  3.0 Minutes:  20.0
# Hours:  3.0 Minutes:  30.0
# Hours:  3.0 Minutes:  40.0
# Hours:  3.0 Minutes:  50.0
# Hours:  4.0 Minutes:  0.0
# Hours:  4.0 Minutes:  10.0
# Hours:  4.0 Minutes:  20.0
# Hours:  4.0 Minutes:  30.0
# Hours:  4.0 Minutes:  40.0
# Hours:  4.0 Minutes:  50.0
# Hours:  5.0 Minutes:  0.0
# Hours:  5.0 Minutes:  10.0
# Hours:  5.0 Minutes:  20.0
# Hours:  5.0 Minutes:  30.0
# Hours:  5.0 Minutes:  40.0
# ...
